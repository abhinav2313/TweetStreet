# %%
# Dependencies
import requests as req
import json
import tweepy
import pandas as pd
import time as t
import os
import matplotlib.pyplot as plt
from config import (consumer_key, consumer_secret, access_token, access_token_secret)
from datetime import datetime, date, time
import numpy as np

# Initialize sentiment analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
#Setup Tweepy API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

#Saving real time stock data in  file
stockHistory = 'stockHistory.txt'
# Base URL for GET requests to retrieve stock data
url = "https://api.iextrading.com/1.0/stock/"
#Opening file
file=open(stockHistory,'w')

#Stock ticker for collecting data
#stocks = ['AAPL', 'V', 'AMZN', 'WMT', 'NFLX', 'NKE', 'M']
stocks = ['V']
# Specify the companies
#target_terms = ["@Apple", "@Visa", "@amazon", "@Walmart", "@netflix", "@Nike", "@Macys"]
target_terms = ["@Visa"]
# Loop through (can change the range if we need to)
def getSentimentAnalysis(handler):
    # Loop through all companies
    
   # Make a dictionary to hold each type of sentiment
        company_sentiment = {
            "compound_list": [], 
            "positive_list": [], 
            "negative_list": [], 
            "neutral_list": []
        }
        public_tweets = api.search(handler, count=100, result_type="recent")

        # Loop through all tweets
        for tweet in public_tweets["statuses"]:

            # Run Vader Analysis on each tweet
            results = analyzer.polarity_scores(tweet["text"])
            compound = results["compound"]
            pos = results["pos"]
            neu = results["neu"]
            neg = results["neg"]

            # Save all info to the corresponding lists
            company_sentiment["compound_list"].append(compound)
            company_sentiment["positive_list"].append(pos)
            company_sentiment["neutral_list"].append(neu)
            company_sentiment["negative_list"].append(neg)
        list_of_sentiment = [np.mean(company_sentiment["compound_list"]),np.mean(company_sentiment["positive_list"]),
                np.mean(company_sentiment["neutral_list"]),np.mean(company_sentiment["negative_list"])]
        return list_of_sentiment
print(str(datetime.now().time()))




stock_market_open_time = time(hour=8, minute=30, second=0, microsecond=0)
stock_market_close_time = time(hour=23, minute=0, second=0, microsecond=0)

file.write(" Counter  ,"+"Corporation          ,"+"Time       ,"+"Stock Ticker       ,"+"Stock Price       ,"+
           "Compound         ,"+"Positive         ,"+"Neutral        ,"+"Negative        \n")
def stockPriceCollectionWithSentiment():
    counter = 0;
    while((datetime.now().time() > stock_market_open_time) & (datetime.now().time() < stock_market_close_time) & counter < 50):
        counter = counter+1
        time_var = datetime.now()
        for stock in stocks:
            print(url+stock+"/quote")
            response = req.get(url+stock+"/quote")
            print("Counter::"+str(counter))
            print(response.json())
            sentiment_anal = getSentimentAnalysis(target_terms[stocks.index(stock)])
            print("Compound::",sentiment_anal[0])
            print("Positive::",sentiment_anal[1])
            print("Neutral::",sentiment_anal[2])
            print("Negative::",sentiment_anal[3])
            print(f"{counter} ,{response.json()['companyName']}          ,{time_var}        ,{response.json()['symbol']}     ,{response.json()['latestPrice']}     ," 
                       +f"{sentiment_anal[0]}      ,{sentiment_anal[1]}      ,{sentiment_anal[2]}      ,{sentiment_anal[3]}\n")
            file.write(f"{counter} ,{response.json()['companyName']}          ,{time_var}        ,{response.json()['symbol']}     ,{response.json()['latestPrice']}     ," 
                       +f"{sentiment_anal[0]}      ,{sentiment_anal[1]}      ,{sentiment_anal[2]}      ,{sentiment_anal[3]}\n")
        file.flush()
            # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file.fileno())
        t.sleep(30)
try:
    stockPriceCollectionWithSentiment()
except KeyboardInterrupt:
    print('\n\nKeyboard exception received. Exiting.')
    file.close()
    exit()
file.close();
# Out:
# 14:08:59.066211
# https://api.iextrading.com/1.0/stock/V/quote
# Counter::1
# {'symbol': 'V', 'companyName': 'Visa Inc.', 'primaryExchange': 'New York Stock Exchange', 'sector': 'Financial Services', 'calculationPrice': 'tops', 'open': 109.55, 'openTime': 1512657010271, 'close': 109.74, 'closeTime': 1512594135894, 'high': 111.28, 'low': 109.45, 'latestPrice': 111.18, 'latestSource': 'IEX real time price', 'latestTime': '3:08:32 PM', 'latestUpdate': 1512677312283, 'latestVolume': 4824017, 'iexRealtimePrice': 111.18, 'iexRealtimeSize': 60, 'iexLastUpdated': 1512677312283, 'delayedPrice': 111.06, 'delayedPriceTime': 1512676431024, 'previousClose': 109.74, 'change': 1.44, 'changePercent': 0.01312, 'iexMarketPercent': 0.01882, 'iexVolume': 90788, 'avgTotalVolume': 7890900, 'iexBidPrice': 108.33, 'iexBidSize': 1300, 'iexAskPrice': 111.2, 'iexAskSize': 200, 'marketCap': 252245929240, 'peRatio': 33.09, 'week52High': 113.62, 'week52Low': 77.19, 'ytdChange': 0.380377358490566}
# Compound:: 0.225244
# Positive:: 0.07474
# Neutral:: 0.92526
# Negative:: 0.0
# 1 ,Visa Inc.          ,2017-12-07 14:08:59.066813        ,V     ,111.18     ,0.22524399999999997      ,0.07474      ,0.9252600000000001      ,0.0
#
# https://api.iextrading.com/1.0/stock/V/quote
# Counter::2
# {'symbol': 'V', 'companyName': 'Visa Inc.', 'primaryExchange': 'New York Stock Exchange', 'sector': 'Financial Services', 'calculationPrice': 'tops', 'open': 109.55, 'openTime': 1512657010271, 'close': 109.74, 'closeTime': 1512594135894, 'high': 111.28, 'low': 109.45, 'latestPrice': 111.165, 'latestSource': 'IEX real time price', 'latestTime': '3:09:21 PM', 'latestUpdate': 1512677361003, 'latestVolume': 4827863, 'iexRealtimePrice': 111.165, 'iexRealtimeSize': 100, 'iexLastUpdated': 1512677361003, 'delayedPrice': 111.06, 'delayedPriceTime': 1512676464931, 'previousClose': 109.74, 'change': 1.425, 'changePercent': 0.01299, 'iexMarketPercent': 0.01895, 'iexVolume': 91488, 'avgTotalVolume': 7890900, 'iexBidPrice': 108.33, 'iexBidSize': 1300, 'iexAskPrice': 111.19, 'iexAskSize': 100, 'marketCap': 252211897139, 'peRatio': 33.08, 'week52High': 113.62, 'week52Low': 77.19, 'ytdChange': 0.380377358490566}
# Compound:: 0.225244
# Positive:: 0.07474
# Neutral:: 0.92526
# Negative:: 0.0
# 2 ,Visa Inc.          ,2017-12-07 14:09:31.584919        ,V     ,111.165     ,0.22524399999999997      ,0.07474      ,0.9252600000000001      ,0.0
#
# https://api.iextrading.com/1.0/stock/V/quote
# Counter::3
# {'symbol': 'V', 'companyName': 'Visa Inc.', 'primaryExchange': 'New York Stock Exchange', 'sector': 'Financial Services', 'calculationPrice': 'tops', 'open': 109.55, 'openTime': 1512657010271, 'close': 109.74, 'closeTime': 1512594135894, 'high': 111.28, 'low': 109.45, 'latestPrice': 111.165, 'latestSource': 'IEX real time price', 'latestTime': '3:09:21 PM', 'latestUpdate': 1512677361003, 'latestVolume': 4832964, 'iexRealtimePrice': 111.165, 'iexRealtimeSize': 100, 'iexLastUpdated': 1512677361003, 'delayedPrice': 111.09, 'delayedPriceTime': 1512676496229, 'previousClose': 109.74, 'change': 1.425, 'changePercent': 0.01299, 'iexMarketPercent': 0.01893, 'iexVolume': 91488, 'avgTotalVolume': 7890900, 'iexBidPrice': 108.33, 'iexBidSize': 1300, 'iexAskPrice': 111.21, 'iexAskSize': 100, 'marketCap': 252211897139, 'peRatio': 33.08, 'week52High': 113.62, 'week52Low': 77.19, 'ytdChange': 0.380377358490566}
# Compound:: 0.225244
# Positive:: 0.07474
# Neutral:: 0.92526
# Negative:: 0.0
# 3 ,Visa Inc.          ,2017-12-07 14:10:02.982342        ,V     ,111.165     ,0.22524399999999997      ,0.07474      ,0.9252600000000001      ,0.0
#
# https://api.iextrading.com/1.0/stock/V/quote
# Counter::4
# {'symbol': 'V', 'companyName': 'Visa Inc.', 'primaryExchange': 'New York Stock Exchange', 'sector': 'Financial Services', 'calculationPrice': 'tops', 'open': 109.55, 'openTime': 1512657010271, 'close': 109.74, 'closeTime': 1512594135894, 'high': 111.28, 'low': 109.45, 'latestPrice': 111.2, 'latestSource': 'IEX real time price', 'latestTime': '3:10:12 PM', 'latestUpdate': 1512677412468, 'latestVolume': 4841139, 'iexRealtimePrice': 111.2, 'iexRealtimeSize': 100, 'iexLastUpdated': 1512677412468, 'delayedPrice': 111.16, 'delayedPriceTime': 1512676527107, 'previousClose': 109.74, 'change': 1.46, 'changePercent': 0.0133, 'iexMarketPercent': 0.01896, 'iexVolume': 91788, 'avgTotalVolume': 7890900, 'iexBidPrice': 111.19, 'iexBidSize': 100, 'iexAskPrice': 111.24, 'iexAskSize': 100, 'marketCap': 252291305374, 'peRatio': 33.1, 'week52High': 113.62, 'week52Low': 77.19, 'ytdChange': 0.380377358490566}
# Compound:: 0.225244
# Positive:: 0.07474
# Neutral:: 0.92526
# Negative:: 0.0
# 4 ,Visa Inc.          ,2017-12-07 14:10:35.435776        ,V     ,111.2     ,0.22524399999999997      ,0.07474      ,0.9252600000000001      ,0.0
#
# https://api.iextrading.com/1.0/stock/V/quote
# Counter::5
# {'symbol': 'V', 'companyName': 'Visa Inc.', 'primaryExchange': 'New York Stock Exchange', 'sector': 'Financial Services', 'calculationPrice': 'tops', 'open': 109.55, 'openTime': 1512657010271, 'close': 109.74, 'closeTime': 1512594135894, 'high': 111.28, 'low': 109.45, 'latestPrice': 111.195, 'latestSource': 'IEX real time price', 'latestTime': '3:10:54 PM', 'latestUpdate': 1512677454872, 'latestVolume': 4841090, 'iexRealtimePrice': 111.195, 'iexRealtimeSize': 100, 'iexLastUpdated': 1512677454872, 'delayedPrice': 111.125, 'delayedPriceTime': 1512676561116, 'previousClose': 109.74, 'change': 1.455, 'changePercent': 0.01326, 'iexMarketPercent': 0.01908, 'iexVolume': 92368, 'avgTotalVolume': 7890900, 'iexBidPrice': 108.33, 'iexBidSize': 1300, 'iexAskPrice': 111.21, 'iexAskSize': 100, 'marketCap': 252279961340, 'peRatio': 33.09, 'week52High': 113.62, 'week52Low': 77.19, 'ytdChange': 0.380377358490566}
# Compound:: 0.222981
# Positive:: 0.07401
# Neutral:: 0.92599
# Negative:: 0.0
# 5 ,Visa Inc.          ,2017-12-07 14:11:07.575777        ,V     ,111.195     ,0.22298099999999998      ,0.07400999999999999      ,0.9259900000000002      ,0.0
#
# https://api.iextrading.com/1.0/stock/V/quote
# Counter::6
# {'symbol': 'V', 'companyName': 'Visa Inc.', 'primaryExchange': 'New York Stock Exchange', 'sector': 'Financial Services', 'calculationPrice': 'tops', 'open': 109.55, 'openTime': 1512657010271, 'close': 109.74, 'closeTime': 1512594135894, 'high': 111.28, 'low': 109.45, 'latestPrice': 111.19, 'latestSource': 'IEX real time price', 'latestTime': '3:11:28 PM', 'latestUpdate': 1512677488639, 'latestVolume': 4864887, 'iexRealtimePrice': 111.19, 'iexRealtimeSize': 400, 'iexLastUpdated': 1512677488639, 'delayedPrice': 111.11, 'delayedPriceTime': 1512676590842, 'previousClose': 109.74, 'change': 1.45, 'changePercent': 0.01321, 'iexMarketPercent': 0.01948, 'iexVolume': 94768, 'avgTotalVolume': 7890900, 'iexBidPrice': 108.33, 'iexBidSize': 1300, 'iexAskPrice': 111.22, 'iexAskSize': 100, 'marketCap': 252268617307, 'peRatio': 33.09, 'week52High': 113.62, 'week52Low': 77.19, 'ytdChange': 0.380377358490566}
# Compound:: 0.222981
# Positive:: 0.07401
# Neutral:: 0.92599
# Negative:: 0.0
# 6 ,Visa Inc.          ,2017-12-07 14:11:39.841249        ,V     ,111.19     ,0.22298099999999998      ,0.07400999999999999      ,0.9259900000000001      ,0.0
#
# https://api.iextrading.com/1.0/stock/V/quote
# Counter::7
# {'symbol': 'V', 'companyName': 'Visa Inc.', 'primaryExchange': 'New York Stock Exchange', 'sector': 'Financial Services', 'calculationPrice': 'tops', 'open': 109.55, 'openTime': 1512657010271, 'close': 109.74, 'closeTime': 1512594135894, 'high': 111.28, 'low': 109.45, 'latestPrice': 111.19, 'latestSource': 'IEX real time price', 'latestTime': '3:12:03 PM', 'latestUpdate': 1512677523152, 'latestVolume': 4876456, 'iexRealtimePrice': 111.19, 'iexRealtimeSize': 100, 'iexLastUpdated': 1512677523152, 'delayedPrice': 111.11, 'delayedPriceTime': 1512676627030, 'previousClose': 109.74, 'change': 1.45, 'changePercent': 0.01321, 'iexMarketPercent': 0.02009, 'iexVolume': 97968, 'avgTotalVolume': 7890900, 'iexBidPrice': 108.33, 'iexBidSize': 1300, 'iexAskPrice': 111.21, 'iexAskSize': 100, 'marketCap': 252268617307, 'peRatio': 33.09, 'week52High': 113.62, 'week52Low': 77.19, 'ytdChange': 0.380377358490566}
# Compound:: 0.222981
# Positive:: 0.07401
# Neutral:: 0.92599
# Negative:: 0.0
# 7 ,Visa Inc.          ,2017-12-07 14:12:11.600785        ,V     ,111.19     ,0.22298099999999998      ,0.07400999999999999      ,0.9259900000000001      ,0.0
# https://api.iextrading.com/1.0/stock/V/quote
# Counter::8
# {'symbol': 'V', 'companyName': 'Visa Inc.', 'primaryExchange': 'New York Stock Exchange', 'sector': 'Financial Services', 'calculationPrice': 'tops', 'open': 109.55, 'openTime': 1512657010271, 'close': 109.74, 'closeTime': 1512594135894, 'high': 111.28, 'low': 109.45, 'latestPrice': 111.185, 'latestSource': 'IEX real time price', 'latestTime': '3:12:35 PM', 'latestUpdate': 1512677555885, 'latestVolume': 4896777, 'iexRealtimePrice': 111.185, 'iexRealtimeSize': 100, 'iexLastUpdated': 1512677555885, 'delayedPrice': 111.115, 'delayedPriceTime': 1512676659592, 'previousClose': 109.74, 'change': 1.445, 'changePercent': 0.01317, 'iexMarketPercent': 0.02017, 'iexVolume': 98768, 'avgTotalVolume': 7890900, 'iexBidPrice': 111.17, 'iexBidSize': 100, 'iexAskPrice': 111.21, 'iexAskSize': 100, 'marketCap': 252257273273, 'peRatio': 33.09, 'week52High': 113.62, 'week52Low': 77.19, 'ytdChange': 0.380377358490566}
# Compound:: 0.222981
# Positive:: 0.07401
# Neutral:: 0.92599
# Negative:: 0.0
# 8 ,Visa Inc.          ,2017-12-07 14:12:43.392055        ,V     ,111.185     ,0.22298099999999998      ,0.07400999999999999      ,0.9259900000000001      ,0.0
